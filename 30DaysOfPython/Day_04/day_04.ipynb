# %%
# Task 01
string = 'Thirty' + ' Days' + ' of' + 'Python'
print(string)

# Task 02
string = 'Coding ' + 'for ' + 'all.'
print(string)
# Out:
# Thirty Days ofPython
# Coding for all.

# %%
company = 'Coding For All'
print(company)

print(len(company))

print(company.upper())

print(company.lower())

print(company.capitalize())

print(company.title())

print(company.swapcase())

print(company[:6])

print(company.__contains__('Coding'))

print(company.index('Coding'))

print(company.rindex('Coding', 0))

print(company.replace('Coding', 'Python'))

print(company.replace('All', 'Everyone'))

print(company.split(' '))

print(company[0])

print(company[-1])

print(company[10])

print(''.join(word[0].upper() for word in company.split()))

print(company.find('C'))

print(company.find('F'))

print(company.rfind('l'))
# Out:
# Coding For All
# 14
# CODING FOR ALL
# coding for all
# Coding for all
# Coding For All
# cODING fOR aLL
# Coding
# True
# 0
# 0
# Python For All
# Coding For Everyone
# ['Coding', 'For', 'All']
# C
# l
#
# CFA
# 0
# 7
# 13

# %%
string = "Facebook, Google, Microsoft, Apple, IBM, Oracle, Amazon"
print(string.split(','))
# Out:
# ['Facebook', ' Google', ' Microsoft', ' Apple', ' IBM', ' Oracle', ' Amazon']

# %%
print("You cannot end a sentence with because because because is a conjunction".index('because'))

print("You cannot end a sentence with because because because is a conjunction".rindex('because'))

print("You cannot end a sentence with because because because is a conjunction".replace(' because because because', ""))
# Out:
# 31
# 47
# You cannot end a sentence with is a conjunction

# %%
print("Coding for All".startswith('Coding'))
print("Coding for all".endswith('coding'))

print("   Coding for all    ".strip())

print('30Python'.isidentifier())
print('thirty_days_of_python'.isidentifier())

python = ['Django', 'Flask', 'Bottle', 'Pyramid', 'Falcon']
print(" ".join(python))

print("I am enjoying this challenge.\nI just wander what is next.")

print("Name\tAge\tCountry\t\tCity\nMahbub\t25\tBangladesh\tSylhet")

radius = 20
area = 3.14 * radius ** 2
print(f"The area of the circle with radius {radius} is {area} meters square.")

print("8 + 6 = 14\n8 - 6 = 2\n8 * 6 = 48\n8 / 6 = 1.33\n8 % 6 = 2\n8 // 6 = 1\n8 ** 6 = 262144")
# Out:
# True
# False
# Coding for all
# False
# True
# Django Flask Bottle Pyramid Falcon
# I am enjoying this challenge.
# I just wander what is next.
# Name	Age	Country		City
# Mahbub	25	Bangladesh	Sylhet
# The area of the circle with radius 20 is 1256.0 meters square.
# 8 + 6 = 14
# 8 - 6 = 2
# 8 * 6 = 48
# 8 / 6 = 1.33
# 8 % 6 = 2
# 8 // 6 = 1
# 8 ** 6 = 262144
